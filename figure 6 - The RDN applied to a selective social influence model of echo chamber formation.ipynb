# %% [markdown]
# # The RDN applied to a selective social influence model of echo chamber formation
#
# A
# different opinion dynamics model that typically produces echo chambers (a, left) [42] can prevent these echo
# chambers from forming by applying the RDN as in Eq. 7 (a, right). Both simulations in (a) have the same
# seed conditions. (b) The number of peaks formed after a 5000 time step simulation was dependent on the
# RDN strength 𝐷, but not clearly on sample size 𝑛 (10 trials each, bars indicate standard error of the mean).
# Note that the selective social influence model can produce more than 2 echo chambers. (c) Applying the
# RDN (𝐷 = 10 and 𝑛 = 1) to an already-polarized network "Pre RDN" took longer to become depolarized,
# if at all (𝑡𝑚𝑎𝑥 = 50000). (d) The number of peaks over time for a range of 𝑛 and 𝐷 (average of 10 trials).
# By 𝑡𝑚𝑎𝑥, most networks had stabilized, with larger D values causing fewer peaks. This change in the
# number of peaks between "$𝑡_{max}$" and "Pre RDN" is shown in (e). Note that for 𝐷 >= 0.3 the simulations
# could become numerically unstable (any change in opinion of > 1 within 10 time steps) and were excluded
# (grey block in "d" indicates less than 3 stable simulations). RDN in examples (a, c) have strength (𝐷) of
# 0.2 and sample size (𝑛) of 1. Other parameters were as in the authors’ original model: 𝑁 = 100, 𝐸 = 400,
# 𝑚 = 10, 𝜖 = 0.5, 𝜇 = 0.5, 𝑝 = 0.5, and 𝑞 = 0.5.[You can use numbers for reference-style link definitions][1]
#
# [42]: Sasahara, K. et al. Social influence and unfollowing accelerate the emergence of echo chambers. J. Comput. Soc. Sci. 4, 381–402 (2021)

# %% [markdown]
# #### imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import logging
import os
import datetime
import itertools
import vaex
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm, Normalize
from matplotlib.cm import ScalarMappable
from pathlib import Path
from tqdm.notebook import tqdm


from opdynamics.metrics.opinions import sample_means
from opdynamics.utils.constants import *
from opdynamics.utils.decorators import optional_fig_ax, hash_repeat
from opdynamics.utils.plot_utils import colorbar_inset, colorline

from social_influence_echo_chamber_model.echo_chamber_dynamics import (
    EchoChamberDynamics,
)
from social_influence_echo_chamber_model.analysis import screen_diversity, num_opinion_peaks

np.random.seed(1337)
sns.set_theme(
    context="notebook",
    style="ticks",
    rc={
        "pdf.fonttype": 42,  # embed font in output
        "svg.fonttype": "none",  # embed font in output
        "figure.facecolor": "white",
        "figure.dpi": 200,
        "axes.facecolor": "None",
        "axes.spines.left": True,
        "axes.spines.bottom": True,
        "axes.spines.right": False,
        "axes.spines.top": False,
    },
)
plt.rcParams["pdf.fonttype"] = 42
plt.rcParams["svg.fonttype"] = "none"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
)
logger = logging.getLogger("nb-social")

# %% [markdown]
# ## plotting
#
# like `opdynamics.visualise.vissocialnetwork`

# %%
@optional_fig_ax
def plot_agents(
    df,
    color_code=True,
    subsample: int = 1,
    ax: plt.Axes = None,
    fig: plt.Figure = None,
    **kwargs
):
    cmap = kwargs.pop("cmap", OPINIONS_CMAP)
    vmin = kwargs.pop("vmin", np.min(df.values))
    vmax = kwargs.pop("vmax", np.max(df.values))
    lw = kwargs.pop("lw", 0.1)

    try:
        sm = ScalarMappable(norm=TwoSlopeNorm(0, vmin, vmax), cmap=cmap)
    except ValueError:
        sm = ScalarMappable(norm=Normalize(vmin, vmax), cmap=cmap)
    import pandas as pd

    df_opinions: pd.DataFrame = df.iloc[::subsample]

    if color_code == "line" or color_code == "lines":
        # using the colorline method allows colors to be dependent on a value, in this case, opinion,
        # but takes much longer to display
        for agent_idx, agent_opinions in df_opinions.iteritems():
            c = sm.to_rgba(agent_opinions.values)
            colorline(
                agent_opinions.index,
                agent_opinions.values,
                c,
                lw=lw,
                ax=ax,
                **kwargs,
            )
    elif color_code:
        for agent_idx, agent_opinions in df_opinions.iteritems():
            c = sm.to_rgba(agent_opinions.values)
            s = kwargs.pop("s", 0.1)
            ax.scatter(
                agent_opinions.index,
                agent_opinions.values,
                c=c,
                s=s,
                lw=0,
                **kwargs,
            )
    else:
        ls = kwargs.pop("ls", "-")
        mec = kwargs.pop("mec", "None")
        cmap_colors = sns.color_palette(cmap, n_colors=df_opinions.shape[0])
        for agent_idx, agent_opinions in df_opinions.iteritems():
            ax.plot(
                df_opinions,
                c=cmap_colors[int(agent_idx)],
                ls=ls,
                mec=mec,
                lw=lw,
                **kwargs,
            )

    ax.set_xlim(0, df_opinions.index[-1])
    ax.set_xlabel(TIME_SYMBOL)
    ax.set_ylabel(OPINION_AGENT_TIME)
    ax.set_ylim(vmin, vmax)

    return fig, ax

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### helper and wrapper functions

# %%
from social_influence_echo_chamber_model.nudge import full_nudge, sample_nudge

def load_csvxz(data_root_dir, file_name) -> pd.DataFrame:
    return pd.read_csv(f"{data_root_dir}/data/{file_name}.csv.xz", index_col=0)

def load_opinions(data_root_dir):
    return load_csvxz(data_root_dir,"opinions")

def load_screen_diversity(data_root_dir):
    return load_csvxz(data_root_dir,"screen_diversity")

def is_unstable(opinions, subsample=100, thresh=1.0):
    """Check if the numerical simulation increases (on average) by more than a threshold"""
    return np.any(opinions.iloc[::subsample].abs().mean(axis=1).diff()>thresh)

def run_simulation(
    n_agents=100,
    n_links=400,
    sns_seed=1,
    l=10,  # screen size
    t_max=10000,  # max steps
    epsilon=0.5,  # bounded confidence parameter
    mu=0.5,  # social influence strength
    p=0.5,  # repost rate
    q=0.5,  # rewiring rate
    following_methods=["Random"],  # , "Respost", "Recommendation"
    nudge_strength=0,
    nudge_sample_size=5,
    nudge_method=full_nudge,
    nudge_delay=0,
    plot=True,
    save_plot=True,
):
    assert nudge_delay < t_max, "nudge_delay must be less than t_max"
    nudge = (nudge_strength, nudge_sample_size, nudge_method)

    name_str = (
        f"{n_agents=}\n{n_links=}\n{l=}\n{t_max=}\n{mu=}\n{p=}\n{q=}\n{epsilon=}"
        f"\n{following_methods=}\n{sns_seed=}\n"
    )
    if nudge[0] > 0:
        name_str += f"{nudge_strength=}\n{nudge_sample_size=}\nnudge_method={nudge_method.__name__})\n"
    else:
        nudge = False
        
    if nudge_delay > 0:
        name_str += f"{nudge_delay=}\n"

    hash_value = hash_repeat(name_str)
    now_str = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    data_root_dir = Path(f"data/data_{hash_value}")

    if not data_root_dir.exists():
        print(f"Creating directory {data_root_dir} for " + name_str.replace('\n', ' '))
        (data_root_dir / "data").mkdir(parents=True)
        (data_root_dir / "network_data").mkdir()

        with open(data_root_dir / "name.txt", "w") as f:
            f.write(name_str)
        s = datetime.datetime.now()

        fileh = logging.FileHandler(f"{data_root_dir}/log.txt", "w")
        formatter = logging.Formatter(
            "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
        )
        fileh.setFormatter(formatter)
        for hdlr in logger.handlers[:]:  # remove old file handler
            if isinstance(hdlr, logging.FileHandler):
                logger.removeHandler(hdlr)
        logger.addHandler(fileh)  # set the new handler

        logger.info(f"Starting simulation.")
        d = EchoChamberDynamics(
            n_agents, n_links, epsilon, sns_seed, l, str(data_root_dir)
        )
        if nudge_delay:
            logger.info(f"nudge=0 for {nudge_delay} steps.")
            d.evolve(nudge_delay, mu, p, q, following_methods, nudge=0)
            remainder_steps = t_max - nudge_delay
            logger.info(f"{nudge=} for {remainder_steps} steps.")
            d.evolve(remainder_steps, mu, p, q, following_methods, nudge=nudge)
        else:
            d.evolve(t_max, mu, p, q, following_methods, nudge=nudge)

        e = datetime.datetime.now()
        logger.info(f"Simulation finished. Took {e - s}")
        logger.removeHandler(fileh)

    if plot:
        opinions = load_opinions(data_root_dir)
        screen_diversity = load_screen_diversity(data_root_dir)
        
        fig, axes = plt.subplots(nrows=2, sharex=True)
        plot_agents(opinions, color_code="line", subsample=10, fig=fig, ax=axes[0])
        plot_agents(screen_diversity, fig=fig, ax=axes[1], cmap="Greens_r")

        for ax in axes:
            ax.axvline(nudge_delay, color="k", alpha=0.3, ls="--")

        axes[0].set_clip_on(False)
        axes[0].set_xlabel("")
        axes[0].annotate(
            "",
            xy=(nudge_delay, opinions.values.max()),
            xytext=(0, 20),
            textcoords="offset points",
            arrowprops=dict(arrowstyle="-|>", color="k"),
            clip_on=False,
            ha="center",
            va="top",
        )
        fig.suptitle(f"{nudge_strength=}, {nudge_sample_size=}")
        if save_plot:
            fig.savefig(f"{data_root_dir}/opinions.jpg")

    return data_root_dir

# %% [markdown]
# ### vary nudge strength `D` and and sample size `n`

# %% [markdown]
# #### immediate nudge

# %%
t_max = 5000
nudge_delay = 0
nudge_strength = 0.2
nudge_sample_size = 5
nudge_method = full_nudge

seeds = [1, 1337, 1001, 926814, 170249, 987654321, 147658, 1235689, 1325896, 9671235]

all_dirs_immediate = []

pbar = tqdm(
    list(itertools.product(seeds, [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0], [1, 5, 10, 15]))
)
level = logging.getLogger("nb-social").getEffectiveLevel()
logging.getLogger("nb-social").setLevel(logging.WARNING)
for seed, D, n in pbar:
    pbar.set_description(f"{seed=}, {D=}, {n=}")
    data_root_dir = run_simulation(
        t_max=t_max,
        sns_seed=seed,
        nudge_strength=D,
        nudge_sample_size=n,
        nudge_method=full_nudge,
        nudge_delay=nudge_delay,
        plot=False,
        save_plot=True,
    )
    all_dirs_immediate.append(data_root_dir)
logging.getLogger("nb-social").setLevel(level)
# Out:
#   0%|          | 0/320 [00:00<?, ?it/s]

# %% [markdown]
# #### delayed nudge

# %%
t_max = 50000
nudge_delay = 5000
nudge_strength = 0.2
nudge_sample_size = 5
nudge_method = full_nudge

seeds = [1, 1337, 1001, 926814, 170249, 987654321, 147658, 1235689, 1325896, 9671235]

all_dirs = []

pbar = tqdm(
    list(itertools.product(seeds, [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0], [1, 5, 10, 15]))
)
level = logging.getLogger("nb-social").getEffectiveLevel()
logging.getLogger("nb-social").setLevel(logging.WARNING)
for seed, D, n in pbar:
    pbar.set_description(f"{seed=}, {D=}, {n=}")
    data_root_dir = run_simulation(
        t_max=t_max,
        sns_seed=seed,
        nudge_strength=D,
        nudge_sample_size=n,
        nudge_method=full_nudge,
        nudge_delay=nudge_delay,
        plot=False,
        save_plot=True,
    )
    all_dirs.append(data_root_dir)
logging.getLogger("nb-social").setLevel(level)
# Out:
#   0%|          | 0/320 [00:00<?, ?it/s]

# %% [markdown]
# ## Data

# %% [markdown]
# ### load data into a single dataframe (using `vaex`)

# %%
root = Path("data/opinions")

def df_from_dirs(root: Path, all_dirs: list):
    root = Path(root)
    if not root.exists():
        root.mkdir(parents=True)

    files = []
    skips = []

    for data_root_dir in tqdm(all_dirs):
        hdf_file = f"{root / data_root_dir.name}.hdf5"

        if Path(hdf_file).exists():
            files.append(hdf_file)
            continue
        opinions = load_opinions(data_root_dir)
        if is_unstable(opinions, thresh=1):
            # skip this simulation
            skips.append(data_root_dir)
            continue
        
        # if opinions.index[-1] < t_max-1:
        #     raise ValueError(f"{opinions.index[-1]} < {t_max-1} but not detected as unstable; {data_root_dir}")

        df = (
            opinions.reset_index()
            .rename(columns={"index": "time"})
            .melt(id_vars="time", var_name="agent", value_name="opinion")
        )

        with open(f"{data_root_dir}/name.txt", "r") as f:
            var_pairs = f.read().strip().split("\n")
        vars_values = [v.split("=") for v in var_pairs]
        for k, v in vars_values:
            df[k] = v
        if "nudge_delay" not in df:
            df["nudge_delay"] = 0
        if "nudge_strength" not in df:
            df["nudge_strength"] = 0
        if "nudge_sample_size" not in df:
            df["nudge_sample_size"] = 0

        vaex.from_pandas(df).export_hdf5(hdf_file)
        files.append(hdf_file)

    return vaex.open_many(files), skips

df, skips = df_from_dirs(root, all_dirs)
df
# Out:
#   0%|          | 0/320 [00:00<?, ?it/s]
# #              time    agent    opinion              n_agents    n_links    l    t_max    mu    p    q    epsilon    following_methods    sns_seed    nudge_strength    nudge_sample_size    nudge_method    nudge_delay
# 0              0       0        -0.4759506499688366  100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     5000
# 1              1       0        -0.4759506499688366  100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     5000
# 2              2       0        -0.4759506499688366  100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     5000
# 3              3       0        -0.4759506499688366  100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     5000
# 4              4       0        -0.4759506499688366  100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     5000
# ...            ...     ...      ...                  ...         ...        ...  ...      ...   ...  ...  ...        ...                  ...         ...               ...                  ...             ...
# 1,184,765,595  49995   99       0.4570872100164609   100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              5000
# 1,184,765,596  49996   99       0.4570872100164609   100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              5000
# 1,184,765,597  49997   99       0.4570872100164609   100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              5000
# 1,184,765,598  49998   99       0.4570872100164609   100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              5000
# 1,184,765,599  49999   99       0.4570872100164609   100         400        10   50000    0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              5000

# %%
df_im, skips = df_from_dirs(root, all_dirs_immediate)
df_im
# Out:
#   0%|          | 0/320 [00:00<?, ?it/s]
# #            time    agent    opinion              n_agents    n_links    l    t_max    mu    p    q    epsilon    following_methods    sns_seed    nudge_strength    nudge_sample_size    nudge_method    nudge_delay
# 0            0       0        -0.4759506499688366  100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     0
# 1            1       0        -0.4759506499688366  100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     0
# 2            2       0        -0.4759506499688366  100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     0
# 3            3       0        -0.4759506499688366  100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     0
# 4            4       0        -0.4759506499688366  100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           1           0.01              1                    full_nudge)     0
# ...          ...     ...      ...                  ...         ...        ...  ...      ...   ...  ...  ...        ...                  ...         ...               ...                  ...             ...
# 159,927,595  4814    99       0.5128381452223137   100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              0
# 159,927,596  4815    99       0.5128381452223137   100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              0
# 159,927,597  4816    99       0.5128381452223137   100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              0
# 159,927,598  4817    99       0.5128381452223137   100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              0
# 159,927,599  4818    99       0.5128381452223137   100         400        10   5000     0.5   0.5  0.5  0.5        ['Random']           9671235     0                 0                    --              0

# %%
df_im_peaks = (
    df_im[(df_im["time"] == df_im["time"].max())]
    .to_pandas_df()
    .groupby(
        ["sns_seed", "nudge_strength", "nudge_sample_size"],
        as_index=False,
    )
    .apply(lambda x: num_opinion_peaks(x["opinion"]))
    .rename(columns={None: "num_peaks"})
)
df_im_peaks = df_im_peaks.convert_dtypes()
df_im_peaks["nudge_strength"] = df_im_peaks["nudge_strength"].astype(float)
df_im_peaks["nudge_sample_size"] = df_im_peaks["nudge_sample_size"].astype(int)
df_im_peaks["num_peaks"] = df_im_peaks["num_peaks"].astype(float)

df_im_avg_peaks = df_im_peaks.groupby(
    ["nudge_strength", "nudge_sample_size"], as_index=False
).agg(
    **{
        "num_peaks": ("num_peaks", "mean"),
        "num_peaks_std": ("num_peaks", "std"),
        "sample_size": ("num_peaks", "count"),
    }
)
df_im_avg_peaks = df_im_avg_peaks[df_im_avg_peaks["sample_size"] >= 3]

df_im_avg_peaks
# Out:
#     nudge_strength  nudge_sample_size  num_peaks  num_peaks_std  sample_size
# 0             0.00                  0   1.777778       0.666667            9
# 1             0.01                  1   2.300000       0.483046           10
# 2             0.01                  5   2.200000       0.788811           10
# 3             0.01                 10   2.200000       0.421637           10
# 4             0.01                 15   2.100000       0.316228           10
# 5             0.05                  1   2.100000       0.316228           10
# 6             0.05                  5   1.900000       0.316228           10
# 7             0.05                 10   2.100000       0.316228           10
# 8             0.05                 15   1.900000       0.567646           10
# 9             0.10                  1   2.000000       0.000000           10
# 10            0.10                  5   2.100000       0.316228           10
# 11            0.10                 10   2.100000       0.316228           10
# 12            0.10                 15   1.900000       0.567646           10
# 13            0.15                  1   1.600000       0.699206           10
# 14            0.15                  5   1.800000       0.421637           10
# 15            0.15                 10   1.600000       0.516398           10
# 16            0.15                 15   1.800000       0.421637           10
# 17            0.20                  1   1.500000       0.527046           10
# 18            0.20                  5   1.500000       0.707107           10
# 19            0.20                 10   1.700000       0.823273           10
# 20            0.20                 15   1.700000       0.674949           10
# 21            0.25                  1   1.300000       0.674949           10
# 22            0.25                  5   1.200000       0.421637           10
# 23            0.25                 10   1.100000       0.316228           10
# 24            0.25                 15   1.500000       0.707107           10
# 25            0.30                  1   0.900000       0.567646           10
# 26            0.30                  5   0.500000       0.527046           10
# 27            0.30                 10   0.700000       0.483046           10
# 28            0.30                 15   0.700000       0.483046           10

# %% [markdown]
# ### select only a few time points and convert to pandas dataframe
# may take a while (2-3 minutes)

# %%
t_max = 50000
nudge_delay = 5000
nudge_strength = 0.2
nudge_sample_size = 5
nudge_method = full_nudge

t_points = list(range(nudge_delay, t_max, nudge_delay))
t_points.append(t_max - 1)
df_t = df[df["time"].isin(t_points)].to_pandas_df()
df_t
# Out:
#          time agent   opinion n_agents n_links   l  t_max   mu    p    q  \
# 0        5000     0 -0.377099      100     400  10  50000  0.5  0.5  0.5
# 1       10000     0 -0.381975      100     400  10  50000  0.5  0.5  0.5
# 2       15000     0 -0.372856      100     400  10  50000  0.5  0.5  0.5
# 3       20000     0 -0.369399      100     400  10  50000  0.5  0.5  0.5
# 4       25000     0 -0.387290      100     400  10  50000  0.5  0.5  0.5
# ...       ...   ...       ...      ...     ...  ..    ...  ...  ...  ...
# 235095  30000    99  0.457087      100     400  10  50000  0.5  0.5  0.5
# 235096  35000    99  0.457087      100     400  10  50000  0.5  0.5  0.5
# 235097  40000    99  0.457087      100     400  10  50000  0.5  0.5  0.5
# 235098  45000    99  0.457087      100     400  10  50000  0.5  0.5  0.5
# 235099  49999    99  0.457087      100     400  10  50000  0.5  0.5  0.5
#
#        epsilon following_methods sns_seed nudge_strength nudge_sample_size  \
# 0          0.5        ['Random']        1           0.01                 1
# 1          0.5        ['Random']        1           0.01                 1
# 2          0.5        ['Random']        1           0.01                 1
# 3          0.5        ['Random']        1           0.01                 1
# 4          0.5        ['Random']        1           0.01                 1
# ...        ...               ...      ...            ...               ...
# 235095     0.5        ['Random']  9671235              0                 0
# 235096     0.5        ['Random']  9671235              0                 0
# 235097     0.5        ['Random']  9671235              0                 0
# 235098     0.5        ['Random']  9671235              0                 0
# 235099     0.5        ['Random']  9671235              0                 0
#
#        nudge_method nudge_delay
# 0       full_nudge)        5000
# 1       full_nudge)        5000
# 2       full_nudge)        5000
# 3       full_nudge)        5000
# 4       full_nudge)        5000
# ...             ...         ...
# 235095         None        5000
# 235096         None        5000
# 235097         None        5000
# 235098         None        5000
# 235099         None        5000
#
# [235100 rows x 17 columns]

# %% [markdown]
# ### reshape and aggregate into specific dataframes

# %%
df_peaks = (
    df_t.groupby(
        ["time", "sns_seed", "nudge_strength", "nudge_sample_size"],
        as_index=False,
    )
    .apply(lambda x: num_opinion_peaks(x["opinion"]))
    .rename(columns={None: "num_peaks"})
)
df_peaks = df_peaks.convert_dtypes()
df_peaks["nudge_strength"] = df_peaks["nudge_strength"].astype(float)
df_peaks["nudge_sample_size"] = df_peaks["nudge_sample_size"].astype(int)
df_peaks["num_peaks"] = df_peaks["num_peaks"].astype(float)

# aggregate over seeds
df_avg_peaks = df_peaks.groupby(
    ["time", "nudge_strength", "nudge_sample_size"], as_index=False
).agg(
    **{
        "num_peaks": ("num_peaks", "mean"),
        "num_peaks_std": ("num_peaks", "std"),
        "sample_size": ("num_peaks", "count"),
    }
)

df_avg_peaks = df_avg_peaks[
    (df_avg_peaks["sample_size"] >= 3) & (~df_avg_peaks["nudge_strength"].isin([0.3]))
]

# peak decrease (first time point ~5000 vs last time point ~50000)
df_peak_decrease = (
    df_peaks.groupby(
        ["sns_seed", "nudge_strength", "nudge_sample_size"], as_index=False
    )
    .apply(
        lambda x: (
            x[x["time"] == x["time"].max()]["num_peaks"].values[0]
            - x[x["time"] == t_points[0]]["num_peaks"].values[0]
        )
    )
    .rename(columns={None: "peak_decrease"})
    .dropna()
)
# aggregated version (e.g. for heatmaps)
df_avg_peak_decrease = df_peak_decrease.groupby(
    ["nudge_strength", "nudge_sample_size"], as_index=False
).agg(
    **{
        "peak_decrease": ("peak_decrease", "mean"),
        "peak_decrease_std": ("peak_decrease", "std"),
        "sample_size": ("peak_decrease", "count"),
    }
)
df_avg_peak_decrease = df_avg_peak_decrease[df_avg_peak_decrease["sample_size"] >= 3]
df_peak_decrease
# Out:
#       sns_seed  nudge_strength  nudge_sample_size  peak_decrease
# 0            1            0.00                  0            0.0
# 1            1            0.01                  1            0.0
# 2            1            0.01                  5            0.0
# 3            1            0.01                 10            0.0
# 4            1            0.01                 15            0.0
# ..         ...             ...                ...            ...
# 202  987654321            0.10                  5            0.0
# 203  987654321            0.10                 10            0.0
# 204  987654321            0.10                 15            0.0
# 205  987654321            0.15                 10            0.0
# 206  987654321            0.15                 15            0.0
#
# [206 rows x 4 columns]

# %% [markdown]
# ## Specific simulations

# %%
COL_MAPPING = {
    "nudge_strength": "D",
    "nudge_sample_size": "n",
    "peak_decrease": "change in # echo chambers",
    "num_peaks": "# echo chambers",
    "num_peaks_std": "std of echo chambers",
}

# %%
# no delay
# baseline and with nudge

fig, axes = plt.subplots(nrows=2, sharex=True, sharey=True)

t_max = 5000
nudge_delay = 0
nudge_strength = 0.2
nudge_sample_size = 1
nudge_method = full_nudge

seed = 1001  # same seed

data_root_dir_base = run_simulation(
    t_max=t_max,
    sns_seed=seed,
    nudge_strength=0,
    plot=False,
)

data_root_dir_nudge = run_simulation(
    t_max=t_max,
    sns_seed=seed,
    nudge_strength=nudge_strength,
    nudge_sample_size=nudge_sample_size,
    nudge_method=nudge_method,
    nudge_delay=nudge_delay,
    plot=False,
)

opinions_base = load_opinions(data_root_dir_base)
opinions_nudge = load_opinions(data_root_dir_nudge)

vmin = min(opinions_base.values.min(), opinions_nudge.values.min())
vmax = max(opinions_base.values.max(), opinions_nudge.values.max())

kwargs = dict(color_code="line", subsample=1, vmin=vmin, vmax=vmax, fig=fig)
plot_agents(opinions_base, ax=axes[0], **kwargs)
plot_agents(opinions_nudge, ax=axes[1], **kwargs)

axes[0].set_xlabel("")
axes[1].set_title(f"D={nudge_strength} n={nudge_sample_size}", va="top")
# Out:
# Text(0.5, 1.0, 'D=0.2 n=1')

# %%
t_max = 50000
nudge_delay = 5000
nudge_strength = 0.2
nudge_sample_size = 1
nudge_method = full_nudge

data_root_dir_delay_1 = run_simulation(
        t_max=t_max,
        sns_seed=926814,
        nudge_strength=0.2,
        nudge_sample_size=1,
        nudge_method=nudge_method,
        nudge_delay=nudge_delay,
        plot=True,
        save_plot=False
    )
num_peaks = num_opinion_peaks(load_opinions(data_root_dir_delay_1).iloc[-1])
print(f"num_peaks={num_peaks}")
data_root_dir_delay_2 = run_simulation(
            t_max=t_max,
            sns_seed=147658,
            nudge_strength=nudge_strength,
            nudge_sample_size=nudge_sample_size,
            nudge_method=nudge_method,
            nudge_delay=nudge_delay,
            plot=True,
            save_plot=False
        )
num_peaks = num_opinion_peaks(load_opinions(data_root_dir_delay_2).iloc[-1])
print(f"num_peaks={num_peaks}")
# Out:
# num_peaks=1
# num_peaks=1

# %% [markdown]
# ## Final figure

# %%
from matplotlib.lines import Line2D

fig, axes = plt.subplot_mosaic(
    """
    AB.C
    ....
    DDDD
    FF.E
    """,
    gridspec_kw={
        "width_ratios": [1, 1, 0.1, 1],
        "height_ratios": [1, 0.1, 1, 1],
        # "wspace": 0.5,
        "hspace": 0.5,
    },
    figsize=(8, 6),
    dpi=200,
)

###############################################################################
print("A & B - baseline vs immediate nudge")
###############################################################################
opinions_base = load_opinions(data_root_dir_base)
opinions_nudge = load_opinions(data_root_dir_nudge)

vmin = min(opinions_base.values.min(), opinions_nudge.values.min())
vmax = max(opinions_base.values.max(), opinions_nudge.values.max())

kwargs = dict(
    color_code="line", subsample=10, vmin=vmin, vmax=vmax, fig=fig, rasterized=True
)
plot_agents(opinions_base, ax=axes["A"], **kwargs)
plot_agents(opinions_nudge, ax=axes["B"], **kwargs)
axes["B"].set_ylabel("")

###############################################################################
print("D - delayed nudge")
###############################################################################
opinions_1 = load_opinions(data_root_dir_delay_1)
opinions_2 = load_opinions(data_root_dir_delay_2)

vmin = min(opinions_1.values.min(), opinions_2.values.min())
vmax = max(opinions_1.values.max(), opinions_2.values.max())

kwargs["vmin"] = vmin
kwargs["vmax"] = vmax
plot_agents(opinions_1, ax=axes["D"], **kwargs)
xticks = list(range(0, t_max + 2, 10000))
xticklabels = xticks[:-1] + ["$t_{max}$"]
if "F" in axes:
    plot_agents(opinions_2, ax=axes["F"], **kwargs)
    axes["F"].set(xlim=(0, t_max + 1), xticks=xticks, xticklabels=xticklabels)
    axes["D"].set(xlim=(0, t_max + 1), xlabel="", xticklabels=[])
else:
    axes["D"].set(xlim=(0, t_max + 1), xticks=xticks, xticklabels=xticklabels)

###############################################################################
print("C and E - quantify echo chambers")
###############################################################################

pal = "crest"

# exclude nudge_strength=0
df_plot = df_im_peaks[df_im_peaks["nudge_strength"] > 0].rename(columns=COL_MAPPING)

sns.lineplot(
    data=df_plot,
    x="D",
    y=COL_MAPPING["num_peaks"],
    palette=pal,
    hue=COL_MAPPING["nudge_sample_size"],
    hue_order=sorted(df_im_peaks["nudge_sample_size"].unique()),
    # style=COL_MAPPING["nudge_sample_size"],
    ax=axes["C"],
    alpha=0.5,
    ci=68,
    err_style="bars",
)
sns.regplot(
    data=df_plot,
    x="D",
    y=COL_MAPPING["num_peaks"],
    color="k",
    ax=axes["C"],
    scatter=False,
    # line_kws={"ls": "--"},
)

axes["C"].set_ylim(1, 3)
# axes["C"].set_xlim(right=0.25)

handles, labels = axes["C"].get_legend_handles_labels()
line = Line2D([0], [0], color="k", ls="--")
axes["C"].legend(
    # handles + [line],
    # labels + ["regression"],
    frameon=False,
    fontsize="small",
    title="n",
    ncol=2,
)

df_avg_peak_decrease["Dn"] = (
    df_avg_peak_decrease["nudge_strength"] + df_avg_peak_decrease["nudge_sample_size"]
)
df_peak_decrease["Dn"] = (
    df_peak_decrease["nudge_strength"] + df_peak_decrease["nudge_sample_size"]
)

df_plot = df_peak_decrease[
    (df_peak_decrease["nudge_strength"] > 0)
    & (df_peak_decrease["Dn"].isin(df_avg_peak_decrease["Dn"].unique()))
].rename(columns=COL_MAPPING)
sns.lineplot(
    data=df_plot,
    x="D",
    y=COL_MAPPING["peak_decrease"],
    palette=pal,
    hue=COL_MAPPING["nudge_sample_size"],
    hue_order=sorted(df_peak_decrease["nudge_sample_size"].unique()),
    # style=COL_MAPPING["nudge_sample_size"],
    ax=axes["E"],
    alpha=0.5,
    ci=68,
    err_style="bars",
    legend=False,
)
sns.regplot(
    data=df_plot,
    x="D",
    y=COL_MAPPING["peak_decrease"],
    color="k",
    ax=axes["E"],
    scatter=False,
    # line_kws={"ls": "--"},
)
# axes["E"].set_ylim(-2, 0)
axes["E"].set_xlim(right=0.3)


###############################################################################
print("final bits")
###############################################################################
for key, ax in axes.items():
    # add ax letter
    ax.annotate(
        key.lower(),
        xy=(0, 1),
        xycoords="axes fraction",
        clip_on=False,
        ha="right",
        va="bottom",
        fontsize="x-large",
        weight="bold",
    )
    if "D" in key:
        ax.hlines(
            y=ax.get_ylim()[1],
            xmin=nudge_delay,
            xmax=t_max,
            color="k",
            lw=3,
            alpha=0.3,
            linestyles="-",
            clip_on=False,
        )
    if "B" in key:
        ax.axhline(ax.get_ylim()[1], color="k", lw=3, alpha=0.3, ls="-", clip_on=False)
# Out:
# A & B - baseline vs immediate nudge
# D - delayed nudge
# C and E - quantify echo chambers
# final bits

# %% [markdown]
# #### Alt

# %%
plt.rcParams["figure.dpi"] = 100


vis_t_points = t_points[:2] + [t_points[len(t_points) // 2]] + t_points[-1:]
t_pal = sns.color_palette("cool_r", n_colors=len(vis_t_points))
D_pal = "crest"

v1_layout = (
    [
        ["Ai"] * 3 + ["."] + ["Bi"] * 5,
        ["Aii"] * 3 + ["."] + ["Bii"] * 5,
        ["."] * 9,
        ["Ci", "Cii", "Ciii", "Civ", "Ccolorbar"] + ["."] + ["D"] * 2 + ["Dcolorbar"],
    ],
)

fig, axes = plt.subplot_mosaic(
    [
        ["Ai"] * 3 + ["Aii"] * 4 + ["."] + ["B"] * 1,
        ["."] * 9,
        ["C"] * 9,
        ["."] * 9,
        ["Di", "Dii", "Diii", "Div", "Dcolorbar"] + ["."] + ["E"] * 3,
    ],
    gridspec_kw={
        "width_ratios": [1, 1, 1, 1, 0.1, 1, 1, 1, 2],
        "height_ratios": [1, 0.1, 1, 0.2, 1.2],
        "wspace": 0.5,
        "hspace": 0.5,
    },
    figsize=(10, 6),
)


t_axes = [ax for key, ax in axes.items() if "Di" in key]
ax_colorbar = axes["Dcolorbar"]
###############################################################################
print("A - baseline vs immediate nudge")
###############################################################################
opinions_base = load_opinions(data_root_dir_base)
opinions_nudge = load_opinions(data_root_dir_nudge)

vmin = min(opinions_base.values.min(), opinions_nudge.values.min())
vmax = max(opinions_base.values.max(), opinions_nudge.values.max())

kwargs = dict(
    color_code="line", subsample=1, vmin=vmin, vmax=vmax, fig=fig, rasterized=True
)
plot_agents(opinions_base, ax=axes["Ai"], **kwargs)
plot_agents(opinions_nudge, ax=axes["Aii"], **kwargs)

# axes["Ai"].set(xlabel="", xticklabels=[])
axes["Aii"].set_ylabel("")

# exclude nudge_strength=0
df_plot = df_im_peaks[df_im_peaks["nudge_strength"] >= 0].rename(columns=COL_MAPPING)

###############################################################################
print("B - # of echo chambers")
###############################################################################

sns.lineplot(
    data=df_plot[df_plot["D"]>0],
    x="D",
    y=COL_MAPPING["num_peaks"],
    palette=D_pal,
    hue=COL_MAPPING["nudge_sample_size"],
    hue_order=sorted(df_im_peaks["nudge_sample_size"].unique()),
    # style=COL_MAPPING["nudge_sample_size"],
    ax=axes["B"],
    alpha=0.5,
    ci=68,
    err_style="bars",
)
sns.regplot(
    data=df_plot,
    x="D",
    y=COL_MAPPING["num_peaks"],
    color="k",
    ax=axes["B"],
    scatter=False,
    # line_kws={"ls": "--"},
)

axes["B"].set_ylim(1, 3)
# axes["B"].set_xlim(right=0.25)

handles, labels = axes["B"].get_legend_handles_labels()
line = Line2D([0], [0], color="k", ls="--")
axes["B"].legend(
    # handles + [line],
    # labels + ["regression"],
    frameon=False,
    fontsize="small",
    title="n",
    ncol=2,
    loc="upper right",
)

###############################################################################
print("C - delayed nudge")
###############################################################################
opinions_1 = load_opinions(data_root_dir_delay_1)

vmin = opinions_1.values.min()
vmax = opinions_1.values.max()

kwargs["vmin"] = vmin
kwargs["vmax"] = vmax
plot_agents(opinions_1, ax=axes["C"], **kwargs)
xticks = list(range(0, t_max + 2, 10000))
xticklabels = xticks[:-1] + ["$t_{max}$"]

if 5000 not in xticks:
    xticks.append(5000)
    xticks.sort()
    xticklabels.insert(xticks.index(5000), "Pre RDN")

axes["C"].set(xlim=(0, t_max + 1), xticks=xticks, xticklabels=xticklabels)

txt_t_points = [f"{t}" for t in vis_t_points]
for text in axes["C"].get_xticklabels():
    if text.get_text() == "Pre RDN":
        text.set_color(t_pal[0])
        text.set_fontweight("bold")
    elif text.get_text() == "$t_{max}$":
        text.set_color(t_pal[-1])
        text.set_fontweight("bold")
    elif text.get_text() in txt_t_points:
        text.set_color(t_pal[txt_t_points.index(text.get_text())])
        text.set_fontweight("bold")

###############################################################################
print("D - heatmaps over time")
###############################################################################
vmin = max(1, df_avg_peaks["num_peaks"].min())
vmax = min(2, df_avg_peaks["num_peaks"].max())
for t, ax, c in zip(vis_t_points, t_axes, t_pal):
    df_wide = (
        df_avg_peaks[(df_avg_peaks["time"] == t) & (df_avg_peaks["nudge_strength"] > 0)]
        .rename(columns=COL_MAPPING)
        .pivot("n", "D", COL_MAPPING["num_peaks"])
    )
    df_wide.columns = df_wide.columns.astype(float)
    df_wide.index = df_wide.index.astype(int)
    df_wide = df_wide.sort_index(axis=1).sort_index(axis=0)
    df_wide.columns = [f"{x:.2f}" for x in df_wide.columns]

    df_wide_std = (
        df_avg_peaks[df_avg_peaks["time"] == t]
        .rename(columns=COL_MAPPING)
        .pivot("n", "D", COL_MAPPING["num_peaks_std"])
    )
    df_wide_std.columns = df_wide_std.columns.astype(float)
    df_wide_std.index = df_wide_std.index.astype(int)
    df_wide_std = df_wide_std.sort_index(axis=1).sort_index(axis=0)
    df_wide_std.columns = [f"{x:.2f}" for x in df_wide_std.columns]

    sns.heatmap(
        df_wide.iloc[::-1],
        vmin=1,
        vmax=3,
        # vmin=df_avg_peaks["num_peaks"].min(),
        # vmax=df_avg_peaks["num_peaks"].max(),
        mask=df_wide.iloc[::-1].isna(),
        cmap="Spectral_r",
        ax=ax,
        square=True,
        cbar=ax == t_axes[-1],
        cbar_ax=ax_colorbar,
        annot=False,
        fmt=".1f",
    )
    # ax.set_xticks(np.array(range(len(df_wide.columns))) + 0.5)
    ax.set_xticklabels(
        # df_wide.columns,
        ax.get_xticklabels(),
        rotation=45,
        fontsize="x-small",
    )
    ax.set_yticklabels(
        ax.get_yticklabels(),
        rotation=0,
        fontsize="x-small",
    )

    ax.set_facecolor("#eeeeee")  # missing values
    if ax != t_axes[0]:
        ax.set(ylabel="", yticklabels=[])
    ax.set_xlabel("D")
    if ax == t_axes[-1]:
        ax.set_title("$t_{max}$", fontsize="large", color=c)
    elif ax==t_axes[0]:
        ax.set_title("Pre RDN", fontsize="large", color=c)
    else:
        ax.set_title(f"{t}", fontsize="large", color=c)

ax_colorbar.set_title("# of echo chambers", fontsize="x-small", ha="right")

###############################################################################
print("E - peak decrease")
###############################################################################

df_avg_peak_decrease["Dn"] = (
    df_avg_peak_decrease["nudge_strength"] + df_avg_peak_decrease["nudge_sample_size"]
)
df_peak_decrease["Dn"] = (
    df_peak_decrease["nudge_strength"] + df_peak_decrease["nudge_sample_size"]
)

df_plot = df_peak_decrease[
    (df_peak_decrease["nudge_strength"] >= 0)
    & (df_peak_decrease["Dn"].isin(df_avg_peak_decrease["Dn"].unique()))
].rename(columns=COL_MAPPING)
sns.lineplot(
    data=df_plot[df_plot["D"]>0],
    x="D",
    y=COL_MAPPING["peak_decrease"],
    palette=pal,
    hue=COL_MAPPING["nudge_sample_size"],
    hue_order=sorted(df_peak_decrease["nudge_sample_size"].unique()),
    # style=COL_MAPPING["nudge_sample_size"],
    ax=axes["E"],
    alpha=0.5,
    ci=68,
    err_style="bars",
    legend=True,
)
sns.regplot(
    data=df_plot,
    x="D",
    y=COL_MAPPING["peak_decrease"],
    color="k",
    ax=axes["E"],
    scatter=False,
    # line_kws={"ls": "--"},
)
# axes["E"].set_ylim(-2, 0)
axes["E"].set_xlim(right=0.3)
axes["E"].set_ylabel("$\Delta$ # echo chambers\n($t_{max} - $Pre RDN)")
axes["E"].legend(
    # handles + [line],
    # labels + ["regression"],
    frameon=False,
    fontsize="small",
    title="n",
    ncol=4,
    loc=(0, 1),
)

###############################################################################
print("final bits")
###############################################################################
axes["E"].set_xticks(np.arange(0, 0.3, 0.05), minor=True)
axes["B"].set_xticks(np.arange(0, 0.3, 0.05), minor=True)

for key, ax in axes.items():
    if "colorbar" not in key:
        # add ax letter
        ax.annotate(
            key.lower(),
            xy=(0, 1),
            xycoords="axes fraction",
            clip_on=False,
            ha="right",
            va="bottom",
            fontsize="x-large",
            weight="bold",
        )
    if "C" in key:
        ax.hlines(
            y=ax.get_ylim()[1],
            xmin=nudge_delay,
            xmax=t_max,
            color="k",
            lw=3,
            alpha=0.3,
            linestyles="-",
            clip_on=False,
        )
        ymin, ymax = ax.get_ylim()
        ax.vlines(
            vis_t_points,
            ymin=ymin,
            ymax=ymax,
            colors=t_pal,
            lw=2,
            alpha=1,
            linestyles="--",
            clip_on=False,
        )
        ax.set_title(f"RDN D=0.2 n=1", fontsize='medium', alpha=0.3)
    elif "Aii" in key:
        ax.axhline(ax.get_ylim()[1], color="k", lw=3, alpha=0.3, ls="-", clip_on=False)
        ax.set_title(f"RDN", fontsize='medium', alpha=0.3)
# Out:
# A - baseline vs immediate nudge
# B - # of echo chambers
# C - delayed nudge
# D - heatmaps over time
# E - peak decrease
# final bits

# %%
print("saving...")
fig.savefig("output/social_influence_model.svg", transparent=True)
print("saved")
# Out:
# saving...
# saved
